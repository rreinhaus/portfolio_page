# %%
import json
import requests

url = "https://www.arbeitnow.com/api/job-board-api"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":[{"slug":"digital-programmatic-media-lead-performance-brand-marketing-all-genders-jomigo-berlin-245939","company_name":"Jomigo","title":"Digital\/Programmatic Media Lead - Performance\/Brand Marketing (all genders)","description":"<strong>Company Description<\/strong><br><p>For our client, a large European e-commerce business, we're looking for&#xa0;a&#xa0;<strong>Programmatic Media Lead - Performance Marketing (all genders).<\/strong>&#xa0;<\/p><p>In this role, you would be responsible for developing and executing the global programmatic &amp; display strategy across pan-European markets. Furthermore, lead all awareness and consideration campaigns.<\/p><br><strong>Job Description<\/strong><br><ul><li>Be responsible for the growth of awareness &amp; consideration metrics through our global programmatic media campaigns<\/li><li>Building Programmatic expertise, and staying ahead of the curve in display and programmatic<\/li><li>Lead asset briefing, campaign creation, optimizati
# ...

# %%
output = json.loads(response.text)

# %%
len(output['data'])
# Out:
# 100

# %%
output['data'][0]
# Out:
# {'slug': 'digital-programmatic-media-lead-performance-brand-marketing-all-genders-jomigo-berlin-245939',
#  'company_name': 'Jomigo',
#  'title': 'Digital/Programmatic Media Lead - Performance/Brand Marketing (all genders)',
# ...

# %%
remote = []
location = []
title = []
url = []
company_name = []

for num in range(len(output['data'])):
    title.append(output['data'][num]['title'])
    location.append(output['data'][num]['location'])
    remote.append(output['data'][num]['remote'])
    url.append(output['data'][num]['url'])
    company_name.append(output['data'][num]['company_name'])

# %%
data_storage = {'Title':title,'Company Name':company_name,'Location':location,'Remote':remote, 'URL':url}

# %%
import pandas as pd
full_data = pd.DataFrame.from_dict(data_storage)
full_data
# Out:
#                                                 Title  \
# 0   Digital/Programmatic Media Lead - Performance/...
# 1                        Information Security Officer
# 2   Werkstudent (m/w/d) Marketing & Unternehmensko...
# 3                  (Junior) Personaldisponent (m/w/d)
# 4   Identity and Access Management Consultant (m/w/d)
# ..                                                ...
# 95                       City Operations Lead, Munich
# 96                        Software Engineer (Android)
# 97  Werkstudent (m/w/div.) zur Unterstützung im Be...
# 98      (Senior) Internal Auditor (Part-time) (m/f/x)
# 99  KFZ Mechatroniker m/w/d Qualitätsprüfung Elekt...
#
#                    Company Name  Location  Remote  \
# 0                        Jomigo    Berlin   False
# 1              Ory Germany GmbH    Munich   False
# 2   Schiller-Eventpersonal GmbH    Berlin   False
# 3   Schiller-Eventpersonal GmbH    Berlin   False
# 4                      Jobverse   Cologne    True
# ...

# %%
full_data.Location.unique()
# Out:
# array(['Berlin', 'Munich', 'Cologne', 'Frankfurt', 'Falkensee', 'Hamburg',
#        'Karlsruhe', 'Stuttgart', 'Eschborn', 'Marktheidenfeld',
#        'Kreischa', 'Marxen', 'Berlin, Berlin, Germany',
#        'Frankfurt am Main, Hesse, Germany', 'Essen', 'Köln',
#        'Stuttgart, Düsseldorf, München, Freiburg', 'Cottbus',
#        'Finsterwalde', 'Marl', 'Nuremberg', 'Bochum', 'Düsseldorf',
#        'Oyten', 'Paderborn', 'Wittlich', 'Bielefeld', 'Wiesbaden',
#        'Saarbrücken', 'Würzburg', 'Brunswick', 'Heidelberg', 'Hanover',
#        'Potsdam', 'Magdeburg', 'Chemnitz', 'Freiburg im Breisgau',
#        'Bremen', 'Kassel', 'Erfurt', 'Mannheim', 'Leipzig', 'Dresden',
#        'Braunschweig', 'Siegen', 'München', 'Eisenach'], dtype=object)

# %%
YOUR_APP_ID = '2b4d7f29'
YOUR_APP_KEY = 'dbe030ecf7634d0df2fd6fa8c9c67b9a'

# %%
    
    
url = f"https://api.adzuna.com/v1/api/jobs/eu/search/1?app_id={YOUR_APP_ID}&app_key={YOUR_APP_KEY}"

url = f'https://api.adzuna.com/v1/api/jobs/eu/search/1?app_id={YOUR_APP_ID}&app_key={YOUR_APP_KEY}&&results_per_page=50&what=Junior%20Product%20Manager&full_time=1'

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
response.text
# Out:
# '{"exception":"UNSUPPORTED_COUNTRY","__CLASS__":"Adzuna::API::Response::Exception","display":"The currently supported ISO 3166 country codes are at, au, be, br, ca, ch, de, es, fr, gb, in, it, mx, nl, nz, pl, ru, sg, us, za","doc":"https://api.adzuna.com/v1/doc"}'

# %%
json.loads(response.text)['results'][1]
# Out:
# {'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#   'display_name': 'Carter Murray'},
#  'contract_type': 'permanent',
#  'salary_min': 27000,
#  'id': '3843778825',
#  'redirect_url': 'https://www.adzuna.co.uk/jobs/land/ad/3843778825?se=JPKwhkaa7RGzMx7GUyr16Q&utm_medium=api&utm_source=2b4d7f29&v=15DA97D56953641454D98A37BD56E1EB5C59A080',
#  'longitude': -0.595448,
#  'salary_is_predicted': '0',
#  'description': 'Carter Murray have exclusively partnered with a large manufacturing brand based in Slough, who are looking for a Junior Product Manager to join their team. The Role As Junior Product Manager you will be actively involved in all product related activity; supporting the implementation of the product strategy to the UK market. Responsibilities Become an expert for your category, including consumer needs and competitor strategy Supporting the full range of existing and new products, organising prom…',
#  'salary_max': 27000,
#  'latitude': 51.5093,
# ...

# %%
category = []
description = []
company = []
title = []
tag = []
url = []

full_res = json.loads(response.text)['results']

for num in range(len(full_res)):
    title.append(full_res[num]['title'])
    tag.append(full_res[num]['category']['tag'])
    description.append(full_res[num]['description'])
    company.append(full_res[num]['company']['display_name'])
    category.append(full_res[num]['category']['label'])
    url.append(full_res[num]['redirect_url'])

# %%
len(company)
# Out:
# 21

# %%
import pandas as pd
data_storage = {'Title':title,'Company Name':company,'Description':description, 'Category':category,'URL':url}
full_data = pd.DataFrame.from_dict(data_storage)
full_data
# Out:
#                                                 Title  \
# 0                              Junior Product Manager
# 1                              Junior Product Manager
# 2                              Junior Product Manager
# 3                              Junior Product Manager
# 4                              Junior Product Manager
# 5                              Junior Product Manager
# 6                 Junior Product Manager - Internship
# 7                   Junior Product Operations Manager
# 8   Junior EMEA ETF Product Management Analyst – 1...
# 9   Product Management Junior / Associate, Alterna...
# 10        Senior Manager - Digital Product Management
# 11                          Interim Portfolio Manager
# 12                             Senior Product Manager
# 13                                 Jr Product Manager
# 14         Senior Product Manager, Data And Analytics
# 15           Graduate Engineer - Industrial Architect
# ...

# %%
'http://api.adzuna.com:80/v1/api/jobs/gb/search/1?app_id={YOUR_APP_ID}&app_key={YOUR_APP_KEY}&results_per_page=20&what=javascript%20developer&what_exclude=java&where=london&sort_by=salary&salary_min=30000&full_time=1&permanent=1&content-type=application/json'
# Out:
# 'http://api.adzuna.com:80/v1/api/jobs/gb/search/1?app_id={YOUR_APP_ID}&app_key={YOUR_APP_KEY}&results_per_page=20&what=javascript%20developer&what_exclude=java&where=london&sort_by=salary&salary_min=30000&full_time=1&permanent=1&content-type=application/json'

# %%
full_time=1&part_time=1&contract=1&permanent=1

# %%
def job_search(role, contract_type, country):
    
    # Basic information
    YOUR_APP_ID = '2b4d7f29'
    YOUR_APP_KEY = 'dbe030ecf7634d0df2fd6fa8c9c67b9a'
    role = role.replace(" ", "%20")
    url = f'https://api.adzuna.com/v1/api/jobs/{country}/search/1?app_id={YOUR_APP_ID}&app_key={YOUR_APP_KEY}&&results_per_page=50&what={role}&{contract_type}=1'
    
    # API call
    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    # Creating a dataframe
    data_storage = {'Title':title,'Company Name':company,'Description':description, 'Category':category,'URL':url}
    full_data = pd.DataFrame.from_dict(data_storage)
    
    return full_data

# %%
job_search_two = job_search('Junior Product Manager','full_time','ru')

# %%
job_search_two
# Out:
#                                                 Title  \
# 0                              Junior Product Manager
# 1                              Junior Product Manager
# 2                              Junior Product Manager
# 3                              Junior Product Manager
# 4                              Junior Product Manager
# 5                              Junior Product Manager
# 6                 Junior Product Manager - Internship
# 7                   Junior Product Operations Manager
# 8   Junior EMEA ETF Product Management Analyst – 1...
# 9   Product Management Junior / Associate, Alterna...
# 10        Senior Manager - Digital Product Management
# 11                          Interim Portfolio Manager
# 12                             Senior Product Manager
# 13                                 Jr Product Manager
# 14         Senior Product Manager, Data And Analytics
# 15           Graduate Engineer - Industrial Architect
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_element(url):
    # Check the website's terms of service
    terms_response = requests.get(url+'/robots.txt')
    if 'Disallow: /' in terms_response.text:
        return "This website cannot be scraped due to terms of service."
    # Make an API call to the website
    cookies = {'cookies_name': 'cookies_value'}
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0;Win64) AppleWebkit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
    response = requests.get(url, cookies=cookies, headers=headers)
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all elements
    elements = soup.find_all()
    # Extract the data and store it in a list
    elements_data = []
    for element in elements:
        class_name = element.get('class')
        if class_name:
            elements_data.append([element.text, class_name])
    # Create a dataframe and write it to a CSV file
    df = pd.DataFrame(elements_data, columns=['data', 'class_name'])
    df.to_csv('scraped_data.csv', index=False)
    return df

# %%
scraped_data = scrape_element('https://www.imdb.com/what-to-watch/fan-favorites/?ref_=hm_fanfav_sm')
scraped_data
# Out:
#                                                   data  \
# 0    MenuMoviesRelease CalendarTop 250 MoviesMost P...
# 1
# 2    MenuMoviesRelease CalendarTop 250 MoviesMost P...
# 3                                                 Menu
# 4
# ..                                                 ...
# 405                           Your Ads Privacy Choices
# 406
# 407
# 408                            IMDb, an Amazon company
# 409                      © 1990-2023 by IMDb.com, Inc.
#
#                                             class_name
# 0    [sc-hTBuwn, eeAlzJ, imdb-header, imdb-header--...
# 1                      [imdb-header__login-state-node]
# 2    [ipc-page-content-container, ipc-page-content-...
# 3    [ipc-responsive-button, ipc-btn--theme-baseAlt...
# 4    [ipc-icon, ipc-icon--menu, ipc-responsive-butt...
# ..                                                 ...
# 405  [ipc-link, ipc-link--baseAlt, ipc-link--touch-...
# 406                            [ipc-inline-list__item]
# ...

# %%
scraped_data.data[0]
# Out:
# "MenuMoviesRelease CalendarTop 250 MoviesMost Popular MoviesBrowse Movies by GenreTop Box OfficeShowtimes & TicketsMovie NewsIndia Movie SpotlightTV ShowsWhat's on TV & StreamingTop 250 TV ShowsMost Popular TV ShowsBrowse TV Shows by GenreTV NewsIndia TV SpotlightWatchWhat to WatchLatest TrailersIMDb OriginalsIMDb PicksIMDb PodcastsAwards & EventsOscarsBest Picture WinnersBest Picture WinnersEmmysSTARmeter AwardsSan Diego Comic-ConNew York Comic-ConSundance Film FestivalToronto Int'l Film FestivalAwards CentralFestival CentralAll EventsCelebsBorn TodayMost Popular CelebsMost Popular CelebsCelebrity NewsCommunityHelp CenterContributor ZonePollsFor Industry ProfessionalsAllAllTitlesTV EpisodesCelebsCompaniesKeywordsAdvanced SearchWatchlistSign InSign InNew Customer?\xa0Create accountENFully supportedEnglish (United States)Partially supportedFrançais (Canada)Français (France)Deutsch (Deutschland)हिंदी (भारत)Italiano (Italia)Português (Brasil)Español (España)Español (México)"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_element(url):
    # Check the website's terms of service
    terms_response = requests.get(url+'/robots.txt')
    if 'Disallow: /' in terms_response.text:
        return "This website cannot be scraped due to terms of service."
    # Make an API call to the website
    cookies = {'cookies_name': 'cookies_value'}
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0;Win64) AppleWebkit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
    response = requests.get(url, cookies=cookies, headers=headers)
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all elements
    elements = soup.find_all()
    # Extract the data and store it in a list
    elements_data = []
    for element in elements:
        class_name = element.get('class')
        if class_name:
            for cname in class_name:
                elements_data.append([', '.join(element.text.split()), cname])
    # Create a dataframe and write it to a CSV file
    df = pd.DataFrame(elements_data, columns=['data', 'class_name'])
    df.to_csv('scraped_data.csv', index=False)
    return df

# %%
scraped_data = scrape_element('https://www.zoopla.co.uk/for-sale/property/london/?q=London&search_source=home')
scraped_data
# Out:
#                                                    data          class_name
# 0     Property, for, sale, in, London, -, ZooplaSkip...               no-js
# 1     Skip, to, main, contentMenuFor, saleTo, rentHo...         portalLight
# 2     Skip, to, main, contentMenuFor, saleTo, rentHo...            c-gBkguA
# 3     Skip, to, main, contentMenuFor, saleTo, rentHo...            c-dhJuzM
# 4     Skip, to, main, contentMenuFor, saleTo, rentHo...              c-PJLV
# ...                                                 ...                 ...
# 4347  ©, 2022, Zoopla, Limited., All, rights, reserved.  c-PJLV-idGEijD-css
# 4348  ©, 2022, Zoopla, Limited., All, rights, reserved.            c-eKeBUq
# 4349  Sold, house, prices, provided, by, Land, Regis...                PJLV
# 4350  Sold, house, prices, provided, by, Land, Regis...    PJLV-ikdlbHP-css
# 4351  Sold, house, prices, provided, by, Land, Regis...            c-eKeBUq
#
# [4352 rows x 2 columns]

# %%
scraped_data['data'][1000]
# Out:
# '1'

# %%
import pandas as pd

# Load the dataframe
df = pd.read_csv('scraped_data.csv')

# Replace missing values in the data column with ''
df['data'].fillna('', inplace=True)

# Define the value to search for
search_value = '£'

# Create a boolean mask to filter the rows
mask = scraped_data['data'].str.contains(search_value)

# Use the mask to filter the dataframe
filtered_df = df[mask]

# Print the filtered dataframe
print(filtered_df)
# Out:
#                                                    data          class_name
# 0     Property, for, sale, in, London, -, ZooplaSkip...               no-js
# 1     Skip, to, main, contentMenuFor, saleTo, rentHo...         portalLight
# 2     Skip, to, main, contentMenuFor, saleTo, rentHo...            c-gBkguA
# 100   LondonThis, area, onlyAny, bedsAny, priceShow,...            c-irbyap
# 101   LondonThis, area, onlyAny, bedsAny, priceShow,...              c-PJLV
# ...                                                 ...                 ...
# 3845  Just, addedGuide, price£1,250,000Bedrooms5Bath...  c-PJLV-ieIaIjy-css
# 3853                             Guide, price£1,250,000              c-PJLV
# 3854                             Guide, price£1,250,000  c-PJLV-ihiazbk-css
# 3855                             Guide, price£1,250,000                PJLV
# 3857                                         £1,250,000            c-bTssUX
#
# [402 rows x 2 columns]

# %%
import pandas as pd

def clean_dataframe(df):
    # check for missing values
    missing_values = df.isnull().sum()
    columns_to_drop = missing_values[missing_values > (0.5 * len(df))].index
    df = df.drop(columns_to_drop, axis=1)
    
    # fill missing values
    for column in df.columns:
        if df[column].isnull().sum() > 0:
            if df[column].dtype == "object":
                df[column].fillna(df[column].mode()[0], inplace=True)
            else:
                df[column].fillna(df[column].mean(), inplace=True)
    
    # remove duplicates
    df = df.drop_duplicates()
    
    # check for inconsistencies
    for column in df.columns:
        if len(df[column].unique()) < len(df[column]) * 0.8:
            print(f"Column {column} has inconsistencies in values.")
            df[column] = df[column].apply(lambda x: x.upper() if type(x) == str else x)
    
    # format columns
    df["date_column"] = pd.to_datetime(df["date_column"], infer_datetime_format=True)
    df["numeric_column"] = df["numeric_column"].astype(float)
    
    return df

# Usage example
#df = pd.read_csv("data.csv")
#clean_df = clean_dataframe(df)

# %%
"""This code will take in a dataframe and checks for missing values, if any column contains more than 50% of missing values it will remove that column. It will fill the missing values with mean or mode depending on the column type. It will remove any duplicate rows and check for inconsistencies within the values used in the dataframe and will print the column name which has inconsistencies. It will format the date and numeric columns as per the requirement and at the end it will return the user with a clean dataset."""
# Out:
# 'This code will take in a dataframe and checks for missing values, if any column contains more than 50% of missing values it will remove that column. It will fill the missing values with mean or mode depending on the column type. It will remove any duplicate rows and check for inconsistencies within the values used in the dataframe and will print the column name which has inconsistencies. It will format the date and numeric columns as per the requirement and at the end it will return the user with a clean dataset.'
